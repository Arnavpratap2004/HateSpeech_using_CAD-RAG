# %% [markdown]
# # CAD-RAG System
#
# This notebook demonstrates the Content Analysis Detection using RAG (CAD-RAG) system.
# The core logic has been moved to `src/rag/engine.py`, ensuring this notebook remains clean and always uses the latest code.

# %%
import sys
import os

# Add project root to path so we can import src
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)

from src.rag.engine import analyze_sentence
# Out:
# c:\Users\Arnav\Desktop\CAD-RAG\src\rag\engine.py:60: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 1.0. An updated version of the class exists in the `langchain-chroma package and should be used instead. To use it run `pip install -U `langchain-chroma` and import as `from `langchain_chroma import Chroma``.
#   slur_lexicon_db = Chroma(client=chroma_client, collection_name="slur_lexicon", embedding_function=embedding_function)

# %% [markdown]
# ## Run Standard Analysis
#
# You can now run the analysis on any sentence using the imported function.

# %%
test_sentence = "All muslims should be kicked out"
result = analyze_sentence(test_sentence)
# Out:
# Analyzing: 'All muslims should be kicked out'
#   Category: Religion-based hate
#   Model Result: HATEFUL
#   Labels: ['identity_hate']
#   RAG Context: Contextual Result for 'Muslim': No recent news events found. | Contextual Result for 'muslims': No r...

# %%
test_sentence_2 = "Have a great day everyone"
result_2 = analyze_sentence(test_sentence_2)
# Out:
# Analyzing: 'Have a great day everyone'
#   Category: General Hate
#   Model Result: HATEFUL
#   Labels: ['identity_hate']
